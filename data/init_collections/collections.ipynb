# %%
# Uninstall pymongo and bson
# !pip uninstall pymongo -y
# !pip uninstall bson -y

# Reinstall pymongo
# !pip install pymongo
# !pip install folium
# Out:
# Found existing installation: pymongo 4.6.1
# Uninstalling pymongo-4.6.1:
#   Successfully uninstalled pymongo-4.6.1
# WARNING: Skipping bson as it is not installed.
# Collecting pymongo
#   Obtaining dependency information for pymongo from https://files.pythonhosted.org/packages/1f/3f/b2e3e18b75d5d42e79939da187efff5ed5aac6a1cc9c0ba21bbe610a33b2/pymongo-4.6.1-cp311-cp311-macosx_10_9_universal2.whl.metadata
#   Using cached pymongo-4.6.1-cp311-cp311-macosx_10_9_universal2.whl.metadata (22 kB)
# Requirement already satisfied: dnspython<3.0.0,>=1.16.0 in /Users/jcasgonq/anaconda3/lib/python3.11/site-packages (from pymongo) (2.6.1)
# Using cached pymongo-4.6.1-cp311-cp311-macosx_10_9_universal2.whl (534 kB)
# Installing collected packages: pymongo
# Successfully installed pymongo-4.6.1
# Requirement already satisfied: folium in /Users/jcasgonq/anaconda3/lib/python3.11/site-packages (0.15.1)
# Requirement already satisfied: branca>=0.6.0 in /Users/jcasgonq/anaconda3/lib/python3.11/site-packages (from folium) (0.7.1)
# Requirement already satisfied: jinja2>=2.9 in /Users/jcasgonq/anaconda3/lib/python3.11/site-packages (from folium) (3.1.2)
# Requirement already satisfied: numpy in /Users/jcasgonq/anaconda3/lib/python3.11/site-packages (from folium) (1.24.3)
# Requirement already satisfied: requests in /Users/jcasgonq/anaconda3/lib/python3.11/site-packages (from folium) (2.31.0)
# Requirement already satisfied: xyzservices in /Users/jcasgonq/anaconda3/lib/python3.11/site-packages (from folium) (2022.9.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /Users/jcasgonq/anaconda3/lib/python3.11/site-packages (from jinja2>=2.9->folium) (2.1.1)
# Requirement already satisfied: charset-normalizer<4,>=2 in /Users/jcasgonq/anaconda3/lib/python3.11/site-packages (from requests->folium) (2.0.4)
# Requirement already satisfied: idna<4,>=2.5 in /Users/jcasgonq/anaconda3/lib/python3.11/site-packages (from requests->folium) (3.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /Users/jcasgonq/anaconda3/lib/python3.11/site-packages (from requests->folium) (1.26.18)
# Requirement already satisfied: certifi>=2017.4.17 in /Users/jcasgonq/anaconda3/lib/python3.11/site-packages (from requests->folium) (2023.11.17)

# %%
import pymongo
import faker
import json
from bson import ObjectId
import hashlib # para id

# %%
# !pip install [biblio]
# Out:
# zsh:1: no matches found: [biblio]

# %%
# Connect to the MongoDB with user and password
db = pymongo.MongoClient("mongodb://localhost:27017/")["simulator"]

# %%
# Create a fake truck data generator
faker.Faker.seed(42)

fake = faker.Faker("es_ES")
trucks = db["trucks"]
#drop the collection
trucks.drop()
for i in range(20):
    truck = {
        "id": fake.license_plate_unified().replace(" ", ""),
        "capacity": fake.random_int(min=10, max=30)
    }
    trucks.insert_one(truck)

# %%
def create_object_id(string):
    hashed = hashlib.sha1(string.encode()).hexdigest()
    object_id = ObjectId(hashed[:24])
    return object_id

# %%
locations = db["locations"]
#drop the collection
locations.drop()
farmacias = json.load(open("../farmacias/farmacias.json", "r"))
#filter farmacias with no coordinates
farmacias = [farmacia for farmacia in farmacias if farmacia["coordinates"] is not None and farmacia["coordinates"]["latitude"] is not None and farmacia["coordinates"]["longitude"] is not None]
# eliminate farmacias with no name or duplicate names
farmacias = {farmacia["name"]: farmacia for farmacia in farmacias}.values()

#add _id
for farmacia in farmacias:
    farmacia["_id"] = create_object_id(farmacia["name"])

locations.insert_many(farmacias)
# Out:
# InsertManyResult([ObjectId('ce6feed06bc1a9e5aff95f04'), ObjectId('47700194cae2115edbe89387'), ObjectId('065e50ccf9bed218e4dc14c6'), ObjectId('e19049464a9467a9a95402ed'), ObjectId('a5f240a9777e72c31a3e69d2'), ObjectId('94a4877361dfc7ba1b87cab4'), ObjectId('15937de4acb61e0a344c6f40'), ObjectId('683d492beb28f2b6843fdc25'), ObjectId('d9cdbdb0da78a71c66b30271'), ObjectId('2c9d3210eab39a36e1f2e21b'), ObjectId('27f95bc631a2522868c52b82'), ObjectId('066eeaec0b80ec50d05f58fa'), ObjectId('b1d80a9ed76950ed2b486c8c'), ObjectId('3647bfc67b4b0b796cf02915'), ObjectId('445701b5f805c76588b9bd89'), ObjectId('80fd8dd40249feffc88145a0'), ObjectId('73ac662a164ad65152e57271'), ObjectId('8bc8213782336471754e8990'), ObjectId('eef6c322fa22198aba0c124e'), ObjectId('85ed504d7134f0484437eca6'), ObjectId('c607448f690edbe3e4451bbd'), ObjectId('58a50ddf91095c052e330fd6'), ObjectId('1793fd9ee539dc62a736ead0'), ObjectId('5247ed8a84c344dfd6061a11'), ObjectId('6912a86b7b6d344a7d91d457'), ObjectId('503420a4936ce669bcbe3a18'), ObjectId('84a60f4319cdc7918a88aefa'), ObjectId('d2234e952ee9412af7fa8f93'), ObjectId('ec46c109a0bc7e15c4f91b28'), ObjectId('bbff948b1699b2091194e4a8'), ObjectId('2dae510b3cdf66702782879f'), ObjectId('e46c5f25f2d337506e641e0d'), ObjectId('77c4b4af011f913b59d3c80a'), ObjectId('dda793138f6614d83cf5f995'), ObjectId('9f8da20d556e4d184d3b780d'), ObjectId('3e0deafc64bb3e671cdaf5c5'), ObjectId('869c800a341b2822745ef5fe'), ObjectId('1957b7bef0a300ead81c688d'), ObjectId('a3f4922de1bcbf3ef0a13c7c'), ObjectId('affa6fe7e83dce1365e3e1fd'), ObjectId('99920d3b2bdf1bea0923524c'), ObjectId('c08227e089a81db63d386676'), ObjectId('5f327a16efec3b298365cfe4'), ObjectId('463e6b0563035fdb0671edb0'), ObjectId('4a1f75581667bb3fe67afc0e'), ObjectId('91c1674987b58ec6e2b0e536'), ObjectId('5183c2618065d513d28a918b'), ObjectId('238bd561d19cc78df63a67f7'), ObjectId('d1c957eaa03f73f827dda1b0'), ObjectId('52febdc8af53d8be1da5e7cf'), ObjectId('03a6499f4a5ee4204ba0f5d2'), ObjectId('f8f1f5c5cdf2874e573c12a3'), ObjectId('c936f530975be8bfb6f2401f'), ObjectId('83457d76d5d6b1ed4399fb19'), ObjectId('3d6b39c10a56d0e42cc9d726'), ObjectId('9bae0417b56cab866bcf7891'), ObjectId('2e3586d6e328e83ad91d20be'), ObjectId('b6d67827d463f9bd5fd11100'), ObjectId('bf95940cfbd52835ce0cf618'), ObjectId('82aae87ca4715e7205986793'), ObjectId('7284a255548e1236db734740'), ObjectId('b2fb6f1d7cf4aefb451a54fc'), ObjectId('6a33d0bcd3624ccb86febf09'), ObjectId('6942f2624e971761b7dd9208'), ObjectId('a90d084e0d6d9e2a3bf99c7f'), ObjectId('3106cd79c968df1fcb2a5ca9'), ObjectId('7851527ad1ae95031ce484cd'), ObjectId('9b3bd9577ef1aaf746083552'), ObjectId('9ee3200a71d14339c397a455'), ObjectId('64bba266de127a5949f52d9a'), ObjectId('0913ab0f37483bf2b1a72664'), ObjectId('fc2ed51a65e1473d8a2859ba'), ObjectId('98049c471fe77a402c0c6379'), ObjectId('41281062b5a24b7992044395'), ObjectId('02daa212163f72d7d2dc4414'), ObjectId('5fc2eee69e4f20f94c2b5420'), ObjectId('c2eb1c63b5b1bb28d06cefaa'), ObjectId('48adbff1f97846a7edab59fa'), ObjectId('a239f00794af715bfd7e46fa'), ObjectId('16a2059695eafcb136ef82c6'), ObjectId('37dc73679e27ac764b7ec239'), ObjectId('170102a9423ffeaaa1ee5030'), ObjectId('365fbe107af15482ce1be1b6'), ObjectId('3b9fbf2b7ce0abfdcdffaf59'), ObjectId('fb5eea977c41f42554288102'), ObjectId('5c3ddcb22a95f99fe3d9a416'), ObjectId('0f4c8b0654e27608c500e311'), ObjectId('99ce67ade13e4d0b896717a7'), ObjectId('4e74c630d560930836983338'), ObjectId('db0e60e6037c08ce560d731d'), ObjectId('01c0ec606d7d4caa083f6d5f'), ObjectId('454935aa7a63afa5b9f8f62a'), ObjectId('8b651f9ef79ad0b6f2d6b4c5'), ObjectId('0931dc706267b6e5a28c915f'), ObjectId('96ab5d20b4b823cb40e5662f'), ObjectId('d72a324be8de57a8f34831c0'), ObjectId('8006b61e975fda65032499a8'), ObjectId('efb85de16cb5f0a396057f58'), ObjectId('9abdf4c45a8cfb3a3dab3566'), ObjectId('d41e99d132831b14f7fee010'), ObjectId('7cbc6a22d00a737375edcb63'), ObjectId('e43817eb219a05b466249117'), ObjectId('9deafec95aa36255db214ba6'), ObjectId('1d6f151cbc3ecac009f87a09'), ObjectId('4d205f32a9d12c681fcb ...

# %%
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_ece791c21818e4b685317c52a135c34a {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_ece791c21818e4b685317c52a135c34a&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_ece791c21818e4b685317c52a135c34a = L.map(
#                 &quot;map_ece791c21818e4b685317c52a135c34a&quot;,
#                 {
#                     center: [40.416775, -3.70379],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 9,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_dd98bb8d65356bdab582281229885b60 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 19, &quot;maxZoom&quot;: 19, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             );
#
#
#             tile_layer_dd98bb8d65356bdab582281229885b60.addTo(map_ece791c21818e4b685317c52a135c34a);
#
#
#             var marker_dde4454bce3a071b51cb2a1e8b68e71d = L.marker(
#                 [40.42732576700565, -3.7041862522159366],
#                 {}
#             ).addTo(map_ece791c21818e4b685317c52a135c34a);
#
#
#         var popup_2477be6534c38d11ca4ff70ea878e9c1 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_8861ad5fd2af8380abbbdb82d9b819cf = $(`&lt;div id=&quot;html_8861ad5fd2af8380abbbdb82d9b819cf&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;plaza del Dos de Mayo, 6, Madrid&lt;/div&gt;`)[0];
#                 popup_2477be6534c38d11ca4ff70ea878e9c1.setContent(html_8861ad5fd2af8380abbbdb82d9b819cf);
#
#
#
#         marker_dde4454bce3a071b51cb2a1e8b68e71d.bindPopup(popup_2477be6534c38d11ca4ff70ea878e9c1)
#         ;
#
#
#
#
#             var marker_cd80986783bfce35ed28750b5866c024 = L.marker(
#                 [40.44159015809918, -3.6962344605258637],
#                 {}
#             ).addTo(map_ece791c21818e4b685317c52a135c34a);
#
#
#         var popup_dbda49faee16e8d3c69f16fed0571c8b = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_d666f30d1ee421178e2cf8b546e7db50 = $(`&lt;div id=&quot;html_d666f30d1ee421178e2cf8b546e7db50&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;calle de Ríos Rosas, 50, Madrid&lt;/div&gt;`)[0];
#                 popup_dbda49faee16e8d3c69f16fed0571c8b.setContent(html_d666f30d1ee421178e2cf8b546e7db50);
#
#
#
#         marker_cd80986783bfce35ed28750b5866c024.bindPopup(popup_dbda49faee16e8d3c69f16fed0571c8b)
#         ;
#
#
#
#
#             var marker_e89de1318b14b9b322aed1393c83b36d = L.marker(
#                 [40.42528356625323, -3.694781349065569],
#                 {}
#             ).addTo(map_ece791c21818e4b685317c52a135c34a);
#
#
#         var popup_c946425de4ae1713e7cc2be012234626 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_32ad5d31dbe86f5d5118b4fe6b0ecc1e = $(`&lt;div id=&quot;html_32ad5d31dbe86f5d5118b4fe6b0ecc1e&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;calle de Argensola, 12, Madrid&lt;/div&gt;`)[0];
#                 popup_c946425de4ae1713e7cc2be012234626.setContent(html_32ad5d31dbe86f5d5118b4fe6b0ecc1e);
#
#
#
#         marker_e89de1318b14b9b322aed1393c83b36d.bindPopup(popup_c946425de4ae1713e7cc2be012234626)
#         ;
#
#
#
#
#             var marker_d5ae5090c4a837c2e223cf7f6069d9ca = L.marker(
#                 [40.42499625549617, -3.67484420244431],
#                 {}
#             ).addTo(map_ece791c21818e4b685317c52a135c34a);
#
#
#         var popup_15a4b90db2c7e7f5a997b5f2f05a6c0c = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_8f198f0a5c2deef30417c06ae22c292e = $(`&lt;div id=&quot;html_8f198f0a5c2deef30417c06ae22c292e&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;calle de Alcalá, 98, Madrid&lt;/div&gt;`)[0];
#                 popup_15a4b90db2c7e7f5a997b5f2f05a6c0c.setContent(html_8f198f0a5c2deef30417c06ae22c292e);
#
#
#
#         marker_d5ae5090c4a837c2e223cf7f6069d9ca.bindPopup(popup_15a4b90db2c7e7f5a997b5f2f05a6c0c)
#         ;
#
#
#
#
#             var marker_1542ade013a9eaa8c65ea982bd99be59 = L.marker(
#                 [40.42373602046807, -3.694447144937114],
#                 {}
#             ).addTo(map_ece791c21818e4b685317c52a135c34a);
#
#
#         var popup_9f0171bb47c7883ef784a94df6bd95a0 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_ae3d8094e878f8a2de619b395385b437 = $(`&lt;div id=&quot;html_ae3d8094e878f8a2de619b395385b437&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;plaza de Salesas, 7, Madrid&lt;/div&gt;`)[0];
#                 popup_9f0171bb47c7883ef784a94df6bd95a0.setContent(html_ae3d8094e878f8a2de619b395385b437);
#
#
#
#         marker_1542ade013a9eaa8c65ea982bd99be59.bindPopup(popup_9f0171bb47c7883ef784a94df6bd95a0)
#         ;
#
#
#
#
#             var marker_026
